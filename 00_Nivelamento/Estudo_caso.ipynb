# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('auto-mpg-original.csv', sep=';')

# %%
df
# Out:
#        mpg cylinders displacement horsepower   weight acceleration model year  \
# 0    18,00      8,00       307,00     130,00  3504,00        12,00      70,00
# 1    15,00      8,00       350,00     165,00  3693,00        11,50      70,00
# 2    18,00      8,00       318,00     150,00  3436,00        11,00      70,00
# 3    16,00      8,00       304,00     150,00  3433,00        12,00      70,00
# 4    17,00      8,00       302,00     140,00  3449,00        10,50      70,00
# ..     ...       ...          ...        ...      ...          ...        ...
# 401  27,00      4,00       140,00     860,00  2790,00        15,60      82,00
# 402  44,00      4,00       970,00     520,00  2130,00        24,60      82,00
# 403  32,00      4,00       135,00     840,00  2295,00        11,60      82,00
# 404  28,00      4,00       120,00     790,00  2625,00        18,60      82,00
# 405  31,00      4,00       119,00     820,00  2720,00        19,40      82,00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    object
#  1   cylinders     406 non-null    object
#  2   displacement  406 non-null    object
#  3   horsepower    400 non-null    object
#  4   weight        406 non-null    object
#  5   acceleration  406 non-null    object
#  6   model year    406 non-null    object
#  7   origin        406 non-null    object
#  8   car name      406 non-null    object
# dtypes: object(9)
# memory usage: 28.7+ KB

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#        mpg cylinders displacement horsepower   weight acceleration model year  \
# 0    18,00      8,00       307,00     130,00  3504,00        12,00      70,00
# 1    15,00      8,00       350,00     165,00  3693,00        11,50      70,00
# 2    18,00      8,00       318,00     150,00  3436,00        11,00      70,00
# 3    16,00      8,00       304,00     150,00  3433,00        12,00      70,00
# 4    17,00      8,00       302,00     140,00  3449,00        10,50      70,00
# ..     ...       ...          ...        ...      ...          ...        ...
# 401  27,00      4,00       140,00     860,00  2790,00        15,60      82,00
# 402  44,00      4,00       970,00     520,00  2130,00        24,60      82,00
# 403  32,00      4,00       135,00     840,00  2295,00        11,60      82,00
# 404  28,00      4,00       120,00     790,00  2625,00        18,60      82,00
# 405  31,00      4,00       119,00     820,00  2720,00        19,40      82,00
#
# ...

# %%
# Substituir vírgulas por pontos e converter a coluna 'mpg' para valores numéricos
df['mpg'] = df['mpg'].str.replace(',', '.').astype(float)

# Encontrar a linha com o valor mais alto na coluna 'mpg'
linha_mpg_maximo = df[df['mpg'] == df['mpg'].max()]

print(linha_mpg_maximo)
# Out:
#       mpg cylinders displacement horsepower   weight acceleration model year  \
# 329  46.6      4,00       860,00     650,00  2110,00        17,90      80,00
#
#     origin   car name
# 329   3,00  mazda glc

# %%
df_cleaned['horsepower'] = df_cleaned['horsepower'].str.replace(',', '.').astype(float)

q3_horsepower = df_cleaned['horsepower'].quantile(0.75)

print(q3_horsepower)
# Out:
# 840.0
# /tmp/ipykernel_58050/713746030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned['horsepower'] = df_cleaned['horsepower'].str.replace(',', '.').astype(float)

# %%
df_cleaned['car name'].drop_duplicates()
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 401              ford mustang gl
# 402                    vw pickup
# 403                dodge rampage
# 404                  ford ranger
# 405                   chevy s-10
# Name: car name, Length: 301, dtype: object

# %%
desvio_padrao = df['mpg'].std()

print("Desvio padrão da coluna 'mpg':", desvio_padrao)
# Out:
# Desvio padrão da coluna 'mpg': 7.8159843125657815
